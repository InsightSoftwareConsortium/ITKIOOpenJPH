# %%
# Install notebook dependencies
import sys
# !{sys.executable} -m pip install -q itkwasm-htj2k matplotlib rich

# %%
from itkwasm_htj2k import decode
import matplotlib.pyplot as plt
from rich import print

# %%
with open('ct_study/f86bc04bd91397953991c13a2cd5dd5f/0ac2f5c1381967a35dc11dde96ac5d30.cache', 'rb') as fp:
    codestream = fp.read()

# %%
image = decode(codestream)

# %%
plt.imshow(image.data)

# %%
print(image)
# Out:
# Image(
#     imageType=ImageType(dimension=2, componentType='int16', pixelType='Scalar', components=1),
#     name='Image',
#     origin=[0.0, 0.0],
#     spacing=[1.0, 1.0],
#     direction=array([[1., 0.],
#        [0., 1.]]),
#     size=[512, 512],
#     metadata=[
#         ['BlockDimensions', [64.0, 64.0]],
#         ['IsReversible', True],
#         ['NumberOfDecompositions', 3],
#         ['NumberOfLayers', 1],
#         ['ProgressionOrder', 2],
#         ['TileOffset', [0.0, 0.0]],
#         ['TileSize', [512.0, 512.0]],
#         ['UseColorTransform', False]
#     ],
#     data=array([[-2000, -2000, -2000, ..., -2000, -2000, -2000],
#        [-2000, -2000, -2000, ..., -2000, -2000, -2000],
#        [-2000, -2000, -2000, ..., -2000, -2000, -2000],
#        ...,
#        [-2000, -2000, -2000, ..., -2000, -2000, -2000],
#        [-2000, -2000, -2000, ..., -2000, -2000, -2000],
#        [-2000, -2000, -2000, ..., -2000, -2000, -2000]], dtype=int16)
# )
